# %%
import pandas as pd

# %%
valo=pd.read_excel('VALO.xlsx',sheet_name='Sheet1')
valo.head()
# Out:
#               Time  Core 0 Clock (perf #3) [MHz]  \
# 0  15:50:35.458000                        3643.5
# 1  15:50:37.894000                        4067.7
# 2  15:50:40.336000                        1885.5
# 3  15:50:42.778000                        1397.5
# 4  15:50:45.219000                        1907.7
#
#    Core 1 Clock (perf #2) [MHz]  Core 2 Clock (perf #1) [MHz]  \
# 0                        4192.5                        4142.6
# 1                        4217.4                        1863.3
# 2                        4242.4                        4267.3
# 3                        4142.6                        4242.4
# 4                        1896.6                        1907.7
#
#    Core 3 Clock (perf #5) [MHz]  Core 4 Clock (perf #6) [MHz]  \
# 0                        4117.6                        1819.0
# 1                        1907.7                        4217.4
# 2                        1885.5                        4242.4
# ...

# %%
valo
# Out:
#                 Time  Core 0 Clock (perf #3) [MHz]  \
# 0    15:50:35.458000                        3643.5
# 1    15:50:37.894000                        4067.7
# 2    15:50:40.336000                        1885.5
# 3    15:50:42.778000                        1397.5
# 4    15:50:45.219000                        1907.7
# ..               ...                           ...
# 785              MIN                        1380.9
# 786              NaN                           NaN
# 787              NaN                           NaN
# 788              NaN                           NaN
# 789              NaN                           NaN
#
#      Core 1 Clock (perf #2) [MHz]  Core 2 Clock (perf #1) [MHz]  \
# 0                          4192.5                        4142.6
# 1                          4217.4                        1863.3
# 2                          4242.4                        4267.3
# 3                          4142.6                        4242.4
# ...

# %%
data=['Time','AVERAGE','CPU (Tctl/Tdie) [°C]']

useful=valo.drop([x for x in valo.columns if x  not in data],axis=1)
useful
useful=useful.dropna()

# %%
import matplotlib.pyplot as plt
import datetime
T=useful['Time']
plt.plot(useful['CPU (Tctl/Tdie) [°C]'],useful['AVERAGE'],)
plot.show
# Out:
# --------------------------------------------
# NameError  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10396/677674221.py in <module>
#       3 T=useful['Time']
#       4 plt.plot(useful['CPU (Tctl/Tdie) [°C]'],useful['AVERAGE'])
# ----> 5 plot.show
#
# NameError: name 'plot' is not defined

# %%
import seaborn as sns

# %%
sns.lineplot(useful[,useful['AVERAGE'],)
# Out:
# c:\users\pranav\documents\code\ml microsoft\ml-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CPU (Tctl/Tdie) [°C]', ylabel='AVERAGE'>
